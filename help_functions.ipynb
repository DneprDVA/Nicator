# %%
import shutil 
import os
import pandas as pd  # pip install pandas
from datetime import datetime
import numpy as np
from pandas import read_csv
from matplotlib import pyplot
from numpy import array
import splitfolders

# %% [markdown]
# ### Unzip .tar files

# %%
# !tar -xzvf "C:/Users/vovad/Desktop/dataset_H4.tar.gz" -C "C:/Users/vovad/Desktop/dataset_divided"

# %% [markdown]
# ### Create TAR file

# %%
import tarfile
import os.path
file_path = 'C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_casting_discs/casting_data/'
basedir = os.path.dirname(file_path)

output_filename = 'dataset_casting_discs_test.tar.gz'
source_dir = 'C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_casting_discs/casting_512x512/'

def make_tarfile(output_filename, source_dir):
    with tarfile.open(output_filename, "w:gz") as tar:
        tar.add(source_dir, arcname=os.path.basename(source_dir))

# %%
make_tarfile(output_filename=output_filename, source_dir=source_dir)

# %% [markdown]
# ### Split files by labels(targets)

# %%
labels = df.sort_values('Label')
class_names = list(labels.Label.unique())
train_images = 'C:/Users/vovad/Desktop/Dataset_H1/'
train_cat = 'C:/Users/vovad/Desktop/Divided/'
for i in class_names:
    os.makedirs(os.path.join('C:/Users/vovad/Desktop/Divided/',str(i)))

# %%
for c in class_names: # Category Name
    for i in list(labels[labels['Label']==c]['filename']): # Image Id
        get_image = os.path.join('C:/Users/vovad/Desktop/Dataset_H1/', i) # Path to Images 
        move_image_to_cat = shutil.copy(get_image, 'C:/Users/vovad/Desktop/Divided/'+str(c))

# %% [markdown]
# ### Find files in folder

# %%
def find(name, path):
    for root, dirs, files in os.walk(path):
        if name in files:
            return os.path.join(root, name)
find('F_64060.jpg', '/content/sample_data/Divided/1/')

# %% [markdown]
# ### Split files to train, val and test

# %%
splitfolders.ratio('C:/Users/vovad/Desktop/Divided/', output="C:/Users/vovad/Desktop/dataset_divided", seed=1337, ratio=(.6, 0.3,0.1))
# Out:
# Copying files: 144978 files [17:14, 140.18 files/s]

# %% [markdown]
# ### Remove all files from folder

# %%
path = '/content/drive/MyDrive/Forex_pics/dataset/'
for file_name in os.listdir(path):
    # construct full file path
    file = path + file_name
    if os.path.isfile(file):        
        os.remove(file)

# %% [markdown]
# ### Move one file to another folder copy part of files to another folder

# %%
import shutil

# absolute path
src_path = '/content/drive/MyDrive/Forex_pics/screenshots.tar.gz'
dst_path = '/content/sample_data/All_pics/screenshots.tar.gz'
shutil.move(src_path, dst_path)

# %%
import shutil
src_path = 'C:/Users/vovad/Desktop/Dataset_H1/'
dst_path = 'C:/Users/vovad/Desktop/experiment/test/'
for i in range(19978):
    shutil.copyfile(src_path+f'S_{125000+i}.jpg', dst_path+f'S_{125000+i}.jpg')

# %% [markdown]
# ### Move all files to another folder

# %%
import os
import shutil

source_folder = r"E:\pynative\reports\\"
destination_folder = r"E:\pynative\account\\"

# fetch all files
for file_name in os.listdir(source_folder):
    # construct full file path
    source = source_folder + file_name
    destination = destination_folder + file_name
    # move only files
    shutil.move(os.path.join(source, file_name), destination)

# %%
import os
import requests
import zipfile
from pathlib import Path

data_path = Path("C:/Users/vovad/Desktop/")
image_path = data_path / "dataset_divided"
def walk_through_dir(dir_path):
  """
  Walks through dir_path returning its contents.
  Args:
    dir_path (str or pathlib.Path): target directory
  
  Returns:
    A print out of:
      number of subdiretories in dir_path
      number of images (files) in each subdirectory
      name of each subdirectory
  """
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(image_path)

# %% [markdown]
# ### randomly move some files from one folder to another python

# %%
import os
import random
import shutil

source = 'C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_red_granules/dataset_ready/train/ok_gran/'
dest = 'C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_red_granules/dataset_ready/val/ok_gran/'
files = os.listdir(source)
no_of_files = len(files) // 10

for file_name in random.sample(files, no_of_files):
    shutil.move(os.path.join(source, file_name), dest)

# %% [markdown]
# ### Create folder

# %%
os.makedirs("/kaggle/working/original")

# %% [markdown]
# ### Rotate images

# %%
import imutils
import cv2

os.chdir('C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_red_granules/full_OK_divided/')
print(os.getcwd())

for i in os.listdir():
    input_image = cv2.imread(i)
    output_image = imutils.rotate(input_image, angle=90)
    cv2.imwrite(i, output_image)
    # print(i) Работает но с ошибкой в конце.
# Out:
# C:\Users\vovad\Desktop\All_Projects\Nicator\dataset_red_granules\full_OK_divided

# %% [markdown]
# ### Enhance image color with OpenCV НЕ ЗАКОНЧЕНО

# %%
#Import the necessary libraries 
import cv2 
import matplotlib.pyplot as plt
import numpy as np
  
# Load the image 
image = cv2.imread('C:/Users/vovad/Desktop/cut/color_copy.jpg', cv2.IMREAD_UNCHANGED) 

# Convert the image from BGR to HSV color space 
image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

print("PhotoShop:", int(image[0][0][0] * 2), int(image[0][0][1] / 2.56), int(image[0][0][2] / 2.56))

print(image[0][0][0], image[0][0][1], image[0][0][2])

# Convert the image back to BGR color space
image2 = cv2.cvtColor(image, cv2.COLOR_HSV2BGR)

# #Save the image 
cv2.imwrite('C:/Users/vovad/Desktop/cut/color_copy.jpg', image2)

# %% [markdown]
# ### Extract images from video OpenCV

# %%
import cv2
import os

cam = cv2.VideoCapture("example.mp4")
currentframe = 0
while(True):
    ret,frame = cam.read()
    if ret:
        name = 'from_video\Frame(' + str(currentframe) + ').jpg'
        cv2.imwrite(name, frame)
        currentframe += 1
    else:
        break
cam.release()
cv2.destroyAllWindows()
print("Done!")

# %% [markdown]
# ### Rename all files in folder

# %%
import cv2
import os
os.chdir('C:/Users/vovad/Desktop/All_Projects/Nicator/color_project/dataset_diff_color/current_resized')
print(os.getcwd())
# Out:
# C:\Users\vovad\Desktop\All_Projects\Nicator\color_project\dataset_diff_color\current_resized

# %%
# Python program to rename all file
# names in your directory 
import os

for count, f in enumerate(os.listdir()):
	f_name, f_ext = os.path.splitext(f)
	f_name = "pic_" + str(count+1)

	new_name = f'{f_name}{f_ext}'
	os.rename(f, new_name)

# %% [markdown]
# ### Split image into multiple pieces

# %%
from PIL import Image
from itertools import product
import os

def tile(filename, dir_in, dir_out, d):
    name, ext = os.path.splitext(filename)
    img = Image.open(os.path.join(dir_in, filename))
    w, h = img.size
    
    grid = product(range(0, h-h%d, d), range(0, w-w%d, d))
    for i, j in grid:
        box = (j, i, j+d, i+d)
        out = os.path.join(dir_out, f'{name}_{i}_{j}{ext}')
        img.crop(box).save(out)

# %%
# d = 1360
# img_cut = 'IMG_20240203_095329.jpg'
# dir_in = 'C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_red_granules/raw_images_0/'
# dir_out = 'C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_red_granules/work_exp/'
# tile(img_cut, dir_in, dir_out, d)

# %%
basedir = os.path.dirname("C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_red_granules/raw_images_0/")
file_list = os.listdir(basedir)
for i,j in enumerate(file_list):
    d = 1360
    # img_cut = f'C:/Users/vovad/Desktop/new/{j}'
    dir_in = 'C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_red_granules/raw_images_0/'
    dir_out = 'C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_red_granules/work_exp/'
    tile(j, dir_in, dir_out, d)

# %% [markdown]
# ### Crop image with OpenCV

# %%
import cv2
import os

basedir_1 = os.path.dirname("C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_diff_color/4/")
model_list_1 = os.listdir(basedir_1)
# Define ROI coordinates

for i,j in enumerate(model_list_1):
    img = cv2.imread(f'C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_diff_color/4/{j}')
    x1, y1 = 1400, 1100
    x2, y2 = 3300, 3000
    cropped_img = img[y1:y2, x1:x2]
    name = 'C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_diff_color/4_cropped/' + str(i) + '.jpg'
    cv2.imwrite(name, cropped_img)

# %%
import cv2
import os
basedir_1 = os.path.dirname("C:/Users/vovad/Desktop/All_Projects/Nicator/dataset_diff_color/4/")

img = cv2.imread('IMG_20240217_152057.jpg')
x1, y1 = 1400, 1100
x2, y2 = 3300, 3000
cropped_img = img[y1:y2, x1:x2]
name = 'C:/Users/vovad/Desktop/All_Projects/Nicator/0.jpg'
cv2.imwrite(name, cropped_img)

# %% [markdown]
# ### Screenshots

# %%
import numpy as np
import pyautogui
import imutils
import cv2
from time import sleep

os.chdir('C:/Users/vovad/Desktop/All_Projects/Nicator/screenshots/')
print(os.getcwd())

for i in range(30):
    image = pyautogui.screenshot()
    image = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    cv2.imwrite(f"shot_s{i}.png", image)
    sleep(2)

# %%
import cv2
import os

os.chdir('C:/Users/vovad/Desktop/All_Projects/Nicator/images/Line_1/separated/')
print(os.getcwd())
# Out:
# C:\Users\vovad\Desktop\All_Projects\Nicator\images\Line_1\separated

# %%
file_path = 'C:/Users/vovad/Desktop/All_Projects/Nicator/images/Line_1/source/'
basedir = os.path.dirname(file_path)
img_path = basedir + "/" + os.listdir(file_path)[0]
d = 960

# %%
from PIL import Image
from itertools import product

def tile(img_path, d):
    img = Image.open(img_path)
    w, h = img.size
    grid = product(range(0, h-h%d, d), range(0, w-w%d, d))
    img_list = []
    for i, j in grid:
        box = (j, i, j+d, i+d)        
        img1 = img.crop(box)
        img_list.append(img1)
    return img_list

# %% [markdown]
# ### Do job by schedule!!!

# %%
import schedule
import time
import csv

headersCSV = ["Дата", "Время", "L контр.", "a контр.", "b контр.", "L", "a", "b", "DeltaE контр.", "DeltaE факт."] # , "Дата/время", "Марка материала"
def job():
    print("I'm working...")
    with open("data.csv", 'w', newline="") as f_object:
        filewriter = csv.writer(f_object, delimiter=',',
                            quotechar='|', quoting=csv.QUOTE_MINIMAL)

schedule.every(1).minutes.do(job)
# schedule.every().hour.do(job)
# schedule.every().day.at("10:30").do(job)
# schedule.every(5).to(10).minutes.do(job)
# schedule.every().monday.do(job)
# schedule.every().wednesday.at("13:15").do(job)

# while True:
#     schedule.run_pending()
#     time.sleep(1)

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
headers_CSV = ["Дата", "Время", "L контр.", "a контр.", "b контр.",\
                                "L", "a", "b", "DeltaE контр.", "DeltaE факт."]
headersCSV = []
for header in headers_CSV:
    headersCSV.append(header.strip('"'))
data = pd.read_csv("color_project/database.csv", header=0, names=headersCSV)

# %%
from PIL import Image
img = Image.open('blin.jpeg')
new_img = img.resize( (450, 450) )
new_img.save( 'blin.jpg')

# %% [markdown]
# ### Увеличение холста изображения (NOT RESOLUTION)

# %%
from PIL import Image, ImageOps

# Open the original image
original_image = Image.open("blin.jpeg")

# Define the new size for the canvas
new_width = 450
new_height = 450

# Create a new image with the desired canvas size and a white background
new_image = Image.new("RGB", (new_width, new_height), (255, 255, 255))

# Calculate the position to paste the original image at the center
x_offset = (new_width - original_image.width) // 2
y_offset = (new_height - original_image.height) // 2

# Paste the original image onto the new image at the calculated position
new_image.paste(original_image, (x_offset, y_offset))

# Save or display the resulting image
new_image.save("blin_0.jpg")
new_image.show()

# %% [markdown]
# ### Edge detection

# %%
import cv2
import matplotlib.pyplot as plt
# Read the original image
img = cv2.imread('test_img.png') 
# Display original image
# cv2.imshow('Original', img)
# cv2.waitKey(0)
 
# Convert to graycsale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Blur the image for better edge detection
img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 
 
# Sobel Edge Detection
sobelx = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobely = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobelxy = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
# Display Sobel Edge Detection Images
# cv2.imshow('Sobel X', sobelx)
# cv2.waitKey(0)
# cv2.imshow('Sobel Y', sobely)
# cv2.waitKey(0)
# cv2.imshow('Sobel X Y using Sobel() function', sobelxy)
# cv2.waitKey(0)
 
# Canny Edge Detection
edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=120) # Canny Edge Detection
# read the image 
contur = cv2.drawContours(img, contours, -1, color=(255, 255, 255), thickness=-1)
# # binarize the image 
# binr = cv2.threshold(edges, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)[1] 
  
# # define the kernel 
# kernel = np.ones((3, 3), np.uint8) 
  
# # opening the image 
# closing = cv2.morphologyEx(binr, cv2.MORPH_CLOSE, kernel, iterations=1) 

# # print the output 
# plt.imshow(closing, cmap='gray')


# Display Canny Edge Detection Image
cv2.imshow('Canny Edge Detection', contur)
cv2.waitKey(0)
 
cv2.destroyAllWindows()

# %%
import imutils
import math
import cv2
import numpy as np
# reading image 
img = cv2.imread('test_img.bmp') 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
  
# setting threshold of gray image 
_, threshold = cv2.threshold(gray, 30, 255, cv2.THRESH_BINARY) 
  
contours, hierarchy = cv2.findContours( 
    threshold, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

for contour in contours:
    cv2.drawContours(img, [contour], 0, (0, 0, 255), 1)

def calculateDistance(x1,y1,x2,y2):
    dist = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    return dist

cnt = contours[1]

(x_axis_raw,y_axis_raw),radius_raw = cv2.minEnclosingCircle(cnt) 

center = (int(x_axis_raw),int(y_axis_raw)) 

dist_to_contour = cv2.pointPolygonTest(contours[1], center, measureDist=True)
radius = int(radius_raw)
H = radius - abs(dist_to_contour)
value_for_alpha = 1 - (H/radius)
alpha = math.acos(value_for_alpha)
chord = 2*radius * math.sin(alpha)

length_contour = cv2.arcLength(contours[1],closed=True)
# center = (int(math.ceil(x_axis_raw)),int(math.ceil(y_axis_raw))) 


dist_points = [calculateDistance(center[0], center[1], contour[0][0], contour[0][1]) for contour in contours[1]]

index_list = [i for i in range(len(dist_points))]
coordinates = []
thresh_for_coordinates = 70

max_values = dict(zip(index_list, dist_points))
max_value_sorted_0 = {k: v for k, v in sorted(max_values.items(), key=lambda item: item[1], reverse=True)}
first_key = [key for key in max_value_sorted_0.keys()][0]
coordinates.append(first_key)

for key, value in dict(max_value_sorted_0).items():
    if key == abs(point_check):
        print(max_value_sorted_0[key])

for key, value in dict(max_value_sorted_0).items():
    if key >= first_key-thresh_for_coordinates and key <= first_key+thresh_for_coordinates:
        del max_value_sorted_0[key]

max_value_sorted_1 = {k: v for k, v in sorted(max_value_sorted_0.items(), key=lambda item: item[1], reverse=True)}
second_key = [key for key in max_value_sorted_1.keys()][0]
coordinates.append(second_key)

for key, value in dict(max_value_sorted_1).items():
    if key >= second_key-thresh_for_coordinates and key <= second_key+thresh_for_coordinates:
        del max_value_sorted_1[key]

max_value_sorted_2 = {k: v for k, v in sorted(max_value_sorted_1.items(), key=lambda item: item[1], reverse=True)}
third_key = [key for key in max_value_sorted_2.keys()][0]
coordinates.append(third_key)

for key, value in dict(max_value_sorted_2).items():
    if key >= third_key-thresh_for_coordinates and key <= third_key+thresh_for_coordinates:
        del max_value_sorted_2[key]
point_0 = contours[1][coordinates[0]][0]
point_1 = contours[1][coordinates[1]][0]
point_2 = contours[1][coordinates[2]][0]
dist_0 = calculateDistance(point_0[0], point_0[1], point_1[0], point_1[1]) # green red
dist_1 = calculateDistance(point_0[0], point_0[1], point_2[0], point_2[1]) # green blue
dist_2 = calculateDistance(point_1[0], point_1[1], point_2[0], point_2[1]) # red blue

# print(min([dist_0, dist_1, dist_2]), dist_0, dist_1, dist_2)
# print(max_value_sorted_2)

cv2.circle(img,center,radius,(0,255,0),1)
# cv2.drawContours(threshold, [c], -1, (0, 255, 255), 2) # contour
cv2.circle(img, (center[0], center[1]), 3, (0,255,0), 1) # center

cv2.circle(img, (contours[1][1224][0][0], contours[1][1224][0][1]), 3, (0, 255, 0), 5)

cv2.circle(img, (point_0[0], point_0[1]), 3, (0, 255, 0), 5) # green
cv2.circle(img, (180, 800), 3, (0,0,255), 2) # red
cv2.circle(img, (690, 750), 3, (255,0,0), 2) # blue

dist_3 = calculateDistance(180, 800, 690, 750)

cv2.line(img, (point_0[0], point_0[1]), (point_1[0], point_1[1]), (0, 255, 0), 1)
cv2.line(img, (point_0[0], point_0[1]), (point_2[0], point_2[1]), (0, 255, 0), 1)
cv2.line(img, (point_1[0], point_1[1]), (point_2[0], point_2[1]), (0, 255, 0), 1)

print(point_1, point_2, dist_2, dist_3)

cv2.imshow('thresh', img)

cv2.waitKey(0) 
cv2.destroyAllWindows()

# %% [markdown]
# ### Обнаружение окружностей на изображении

# %%
import cv2 
import numpy as np 
  
# Read image. 
img = cv2.imread('test_img_expand.png', cv2.IMREAD_COLOR) 
  
# Convert to grayscale. 
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
  
# Blur using 3 * 3 kernel. 
gray_blurred = cv2.blur(gray, (3, 3))
  
# Apply Hough transform on the blurred image. 
detected_circles = cv2.HoughCircles(gray_blurred,  
                   cv2.HOUGH_GRADIENT, 1, 100, param1 = 30, 
               param2 = 55, minRadius = 150, maxRadius = 300) 
  
# Draw circles that are detected. 
if detected_circles is not None: 
  
    # Convert the circle parameters a, b and r to integers. 
    detected_circles = np.uint16(np.around(detected_circles)) 
  
    for pt in detected_circles[0, :]: 
        a, b, r = pt[0], pt[1], pt[2] 
  
        # Draw the circumference of the circle. 
        cv2.circle(img, (a, b), r, (0, 255, 0), 1) 
  
        # Draw a small circle (of radius 1) to show the center. 
        cv2.circle(img, (a, b), 1, (0, 0, 255), 1) 
        cv2.imshow("Detected Circle", img)
        cv2.waitKey(0)
